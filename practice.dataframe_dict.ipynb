# %%
import numpy as np
import pandas as pd
import matplotlib .pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv(r'file:///C:\Users\Admin\Downloads\data_population_world.csv')
d
# Out:
#         Country Name Country Code    Indicator Name Indicator Code  \
# 0              Aruba          ABW  Población, total    SP.POP.TOTL
# 1                NaN          AFE  Población, total    SP.POP.TOTL
# 2         Afganistán          AFG  Población, total    SP.POP.TOTL
# 3                NaN          AFW  Población, total    SP.POP.TOTL
# 4             Angola          AGO  Población, total    SP.POP.TOTL
# ..               ...          ...               ...            ...
# 261           Kosovo          XKX  Población, total    SP.POP.TOTL
# 262  Yemen, Rep. del          YEM  Población, total    SP.POP.TOTL
# 263        Sudáfrica          ZAF  Población, total    SP.POP.TOTL
# 264           Zambia          ZMB  Población, total    SP.POP.TOTL
# 265         Zimbabwe          ZWE  Población, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# ...

# %%
d.shape
# Out:
# (266, 67)

# %%
d.size
# Out:
# 17822

# %%
d.head()
# Out:
#   Country Name Country Code    Indicator Name Indicator Code         1960  \
# 0        Aruba          ABW  Población, total    SP.POP.TOTL      54608.0
# 1          NaN          AFE  Población, total    SP.POP.TOTL  130692579.0
# 2   Afganistán          AFG  Población, total    SP.POP.TOTL    8622466.0
# 3          NaN          AFW  Población, total    SP.POP.TOTL   97256290.0
# 4       Angola          AGO  Población, total    SP.POP.TOTL    5357195.0
#
#           1961         1962         1963         1964         1965  ...  \
# 0      55811.0      56682.0      57475.0      58178.0      58782.0  ...
# 1  134169237.0  137835590.0  141630546.0  145605995.0  149742351.0  ...
# 2    8790140.0    8969047.0    9157465.0    9355514.0    9565147.0  ...
# 3   99314028.0  101445032.0  103667517.0  105959979.0  108336203.0  ...
# 4    5441333.0    5521400.0    5599827.0    5673199.0    5736582.0  ...
#
#           2013         2014         2015         2016         2017  \
# ...

# %%
d.isna().sum()
# Out:
# Country Name        2
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2018                1
# 2019                1
# 2020                1
# 2021                1
# Unnamed: 66       266
# Length: 67, dtype: int64

# %%
d.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
d.tail()
# Out:
#         Country Name Country Code    Indicator Name Indicator Code  \
# 261           Kosovo          XKX  Población, total    SP.POP.TOTL
# 262  Yemen, Rep. del          YEM  Población, total    SP.POP.TOTL
# 263        Sudáfrica          ZAF  Población, total    SP.POP.TOTL
# 264           Zambia          ZMB  Población, total    SP.POP.TOTL
# 265         Zimbabwe          ZWE  Población, total    SP.POP.TOTL
#
#            1960        1961        1962        1963        1964        1965  \
# 261    947000.0    966000.0    994000.0   1022000.0   1050000.0   1078000.0
# 262   5542459.0   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0
# 263  16520441.0  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0
# 264   3119430.0   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0
# 265   3806310.0   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0
#
#      ...        2013        2014        2015        2016        2017  \
# ...

# %%
d.shape
# Out:
# (266, 67)

# %%
d
# Out:
#         Country Name Country Code    Indicator Name Indicator Code  \
# 0              Aruba          ABW  Población, total    SP.POP.TOTL
# 1                NaN          AFE  Población, total    SP.POP.TOTL
# 2         Afganistán          AFG  Población, total    SP.POP.TOTL
# 3                NaN          AFW  Población, total    SP.POP.TOTL
# 4             Angola          AGO  Población, total    SP.POP.TOTL
# ..               ...          ...               ...            ...
# 261           Kosovo          XKX  Población, total    SP.POP.TOTL
# 262  Yemen, Rep. del          YEM  Población, total    SP.POP.TOTL
# 263        Sudáfrica          ZAF  Población, total    SP.POP.TOTL
# 264           Zambia          ZMB  Población, total    SP.POP.TOTL
# 265         Zimbabwe          ZWE  Población, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# ...

# %%
sum(d.duplicated())
# Out:
# 0

# %%
len(d)
# Out:
# 266

# %%
d.fillna(0)
# Out:
#         Country Name Country Code    Indicator Name Indicator Code  \
# 0              Aruba          ABW  Población, total    SP.POP.TOTL
# 1                  0          AFE  Población, total    SP.POP.TOTL
# 2         Afganistán          AFG  Población, total    SP.POP.TOTL
# 3                  0          AFW  Población, total    SP.POP.TOTL
# 4             Angola          AGO  Población, total    SP.POP.TOTL
# ..               ...          ...               ...            ...
# 261           Kosovo          XKX  Población, total    SP.POP.TOTL
# 262  Yemen, Rep. del          YEM  Población, total    SP.POP.TOTL
# 263        Sudáfrica          ZAF  Población, total    SP.POP.TOTL
# 264           Zambia          ZMB  Población, total    SP.POP.TOTL
# 265         Zimbabwe          ZWE  Población, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# ...

# %%
d
# Out:
#         Country Name Country Code    Indicator Name Indicator Code  \
# 0              Aruba          ABW  Población, total    SP.POP.TOTL
# 1                NaN          AFE  Población, total    SP.POP.TOTL
# 2         Afganistán          AFG  Población, total    SP.POP.TOTL
# 3                NaN          AFW  Población, total    SP.POP.TOTL
# 4             Angola          AGO  Población, total    SP.POP.TOTL
# ..               ...          ...               ...            ...
# 261           Kosovo          XKX  Población, total    SP.POP.TOTL
# 262  Yemen, Rep. del          YEM  Población, total    SP.POP.TOTL
# 263        Sudáfrica          ZAF  Población, total    SP.POP.TOTL
# 264           Zambia          ZMB  Población, total    SP.POP.TOTL
# 265         Zimbabwe          ZWE  Población, total    SP.POP.TOTL
#
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'name':['Ashwin','Virat','Dinesh','Rohit','Hardik','Ravindra','shami','Rahul','Kuldeep','Rishabh','Pujara'],
                   'place':['Pune','Satara','Sangli','Solapur','Kolhapur','Pune','satara','Sangli','Solapur','Pune','Satara'],
                  'age':[42,20,25,36,28,24,45,25,21,19,45]})
df
# Out:
#         name     place  age
# 0     Ashwin      Pune   42
# 1      Virat    Satara   20
# 2     Dinesh    Sangli   25
# 3      Rohit   Solapur   36
# 4     Hardik  Kolhapur   28
# 5   Ravindra      Pune   24
# 6      shami    satara   45
# 7      Rahul    Sangli   25
# 8    Kuldeep   Solapur   21
# 9    Rishabh      Pune   19
# 10    Pujara    Satara   45

# %%
df.shape
# Out:
# (11, 3)

# %%
#df['name']
#df.name
df[['name']]
# Out:
#         name
# 0     Ashwin
# 1      Virat
# 2     Dinesh
# 3      Rohit
# 4     Hardik
# 5   Ravindra
# 6      shami
# 7      Rahul
# 8    Kuldeep
# 9    Rishabh
# 10    Pujara

# %%
df.columns
# Out:
# Index(['name', 'place', 'age'], dtype='object')

# %%
df.head(3)
# Out:
#      name   place  age
# 0  Ashwin    Pune   42
# 1   Virat  Satara   20
# 2  Dinesh  Sangli   25

# %%
#df.sample(5)
#df.name.sample(5)
df[['name']].loc[[5,4,8,6,7]]
# Out:
#        name
# 5  Ravindra
# 4    Hardik
# 8   Kuldeep
# 6     shami
# 7     Rahul

# %%
df.tail(3)
# Out:
#        name    place  age
# 8   Kuldeep  Solapur   21
# 9   Rishabh     Pune   19
# 10   Pujara   Satara   45

# %%
#df[df.age==42]
df.query('age==42')
# Out:
#      name place  age
# 0  Ashwin  Pune   42

# %%
df.query('place=="Kolhapur"')
# Out:
#      name     place  age
# 4  Hardik  Kolhapur   28

# %%
df.query('place=="Pune" and age<30')
# Out:
#        name place  age
# 5  Ravindra  Pune   24
# 9   Rishabh  Pune   19

# %%
df.age.value_counts()
# Out:
# 25    2
# 45    2
# 42    1
# 20    1
# 36    1
# 28    1
# 24    1
# 21    1
# 19    1
# Name: age, dtype: int64

# %%
df.place.value_counts()
# Out:
# Pune        3
# Satara      2
# Sangli      2
# Solapur     2
# Kolhapur    1
# satara      1
# Name: place, dtype: int64

# %%
df.place.unique()
df.place.nunique()
# Out:
# 6

# %%
df.age.min()
df.query('age==19')
df[df.age==df.age.min()]
# Out:
#       name place  age
# 9  Rishabh  Pune   19

# %%
df[df['name'].str.len()>5]
# Out:
#         name     place  age
# 0     Ashwin      Pune   42
# 2     Dinesh    Sangli   25
# 4     Hardik  Kolhapur   28
# 5   Ravindra      Pune   24
# 8    Kuldeep   Solapur   21
# 9    Rishabh      Pune   19
# 10    Pujara    Satara   45

# %%
df[df['name'].str.startswith('R')]
# Out:
#        name    place  age
# 3     Rohit  Solapur   36
# 5  Ravindra     Pune   24
# 7     Rahul   Sangli   25
# 9   Rishabh     Pune   19

# %%
df[['name']]
# Out:
#         name
# 0     Ashwin
# 1      Virat
# 2     Dinesh
# 3      Rohit
# 4     Hardik
# 5   Ravindra
# 6      shami
# 7      Rahul
# 8    Kuldeep
# 9    Rishabh
# 10    Pujara

# %%
df.query('age%4==0')
# Out:
#        name     place  age
# 1     Virat    Satara   20
# 3     Rohit   Solapur   36
# 4    Hardik  Kolhapur   28
# 5  Ravindra      Pune   24

# %%
df[['age']]
# Out:
#     age
# 0    42
# 1    20
# 2    25
# 3    36
# 4    28
# 5    24
# 6    45
# 7    25
# 8    21
# 9    19
# 10   45

# %%
df[['place']].
# Out:
# 0         Pune
# 1       Satara
# 2       Sangli
# 3      Solapur
# 4     Kolhapur
# 5         Pune
# 6       satara
# 7       Sangli
# 8      Solapur
# 9         Pune
# 10      Satara
# Name: place, dtype: object

# %%
df1={'Pune':12,'Satara':11,'Sangli':10,'Solapur':13,'Kolhapur':9,'Pune':12,'satara':11,'Sangli':10,'Solapur':13,'Pune':12,'Satara':11}
df1
# Out:
# {'Pune': 12,
#  'Satara': 11,
#  'Sangli': 10,
#  'Solapur': 13,
#  'Kolhapur': 9,
#  'satara': 11}

# %%
df = pd.DataFrame({'name':['Ashwin','Virat','Dinesh','Rohit','Hardik','Ravindra','shami','Rahul','Kuldeep','Rishabh','Pujara'],
                   'place':['Pune','Satara','Sangli','Solapur','Kolhapur','Pune','Satara','Sangli','Solapur','Pune','Satara'],
                  'age':[42,20,25,36,28,24,45,25,21,19,45]})
df
# Out:
#         name     place  age
# 0     Ashwin      Pune   42
# 1      Virat    Satara   20
# 2     Dinesh    Sangli   25
# 3      Rohit   Solapur   36
# 4     Hardik  Kolhapur   28
# 5   Ravindra      Pune   24
# 6      shami    Satara   45
# 7      Rahul    Sangli   25
# 8    Kuldeep   Solapur   21
# 9    Rishabh      Pune   19
# 10    Pujara    Satara   45

# %%
df.query('age>30')
# Out:
#       name    place  age
# 0   Ashwin     Pune   42
# 3    Rohit  Solapur   36
# 6    shami   Satara   45
# 10  Pujara   Satara   45

# %%
df[df.name.str.startswith('A')]
# Out:
#      name place  age
# 0  Ashwin  Pune   42

# %%
df[df.name.str.endswith('a')]
# Out:
#         name   place  age
# 5   Ravindra    Pune   24
# 10    Pujara  Satara   45

# %%
df[df.name=='Rishabh']
df[df.age==19]
# Out:
#       name place  age
# 9  Rishabh  Pune   19

# %%
df.query('name=="Rishabh"').age
# Out:
# 9    19
# Name: age, dtype: int64

# %%
df.query('place=="Satara"').name
# Out:
# 1      Virat
# 6      shami
# 10    Pujara
# Name: name, dtype: object

# %%
df.query('age<=25')
# Out:
#        name    place  age
# 1     Virat   Satara   20
# 2    Dinesh   Sangli   25
# 5  Ravindra     Pune   24
# 7     Rahul   Sangli   25
# 8   Kuldeep  Solapur   21
# 9   Rishabh     Pune   19

# %%
df.query('place=="Sangli"')
# Out:
#      name   place  age
# 2  Dinesh  Sangli   25
# 7   Rahul  Sangli   25

# %%
df
# Out:
#         name     place  age
# 0     Ashwin      Pune   42
# 1      Virat    Satara   20
# 2     Dinesh    Sangli   25
# 3      Rohit   Solapur   36
# 4     Hardik  Kolhapur   28
# 5   Ravindra      Pune   24
# 6      shami    Satara   45
# 7      Rahul    Sangli   25
# 8    Kuldeep   Solapur   21
# 9    Rishabh      Pune   19
# 10    Pujara    Satara   45

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
df.isna()
# Out:
#      name  place    age
# 0   False  False  False
# 1   False  False  False
# 2   False  False  False
# 3   False  False  False
# 4   False  False  False
# 5   False  False  False
# 6   False  False  False
# 7   False  False  False
# 8   False  False  False
# 9   False  False  False
# 10  False  False  False

# %%
df.query('name=="Virat"').age
# Out:
# 1    20
# Name: age, dtype: int64

# %%
new_row=pd.DataFrame({'name':['Saurabh'],'place':'[Kolhapur]','age':[25]})
new_row
# Out:
#       name       place  age
# 0  Saurabh  [Kolhapur]   25

# %%
df
# Out:
#         name     place  age
# 0     Ashwin      Pune   42
# 1      Virat    Satara   20
# 2     Dinesh    Sangli   25
# 3      Rohit   Solapur   36
# 4     Hardik  Kolhapur   28
# 5   Ravindra      Pune   24
# 6      shami    Satara   45
# 7      Rahul    Sangli   25
# 8    Kuldeep   Solapur   21
# 9    Rishabh      Pune   19
# 10    Pujara    Satara   45

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'name':['Ashwin','Virat','Dinesh','Rohit','Hardik','Ravindra','shami','Rahul','Kuldeep','Rishabh','Pujara'],
                   'place':['Pune','Satara','Sangli','Solapur','Kolhapur','Pune','Satara','Sangli','Solapur','Pune','Satara'],
                  'age':[42,20,25,36,28,24,45,25,21,19,45]})
df
# Out:
#         name     place  age
# 0     Ashwin      Pune   42
# 1      Virat    Satara   20
# 2     Dinesh    Sangli   25
# 3      Rohit   Solapur   36
# 4     Hardik  Kolhapur   28
# 5   Ravindra      Pune   24
# 6      shami    Satara   45
# 7      Rahul    Sangli   25
# 8    Kuldeep   Solapur   21
# 9    Rishabh      Pune   19
# 10    Pujara    Satara   45

# %%
new_row=pd.DataFrame({'name':['Saurabh'],'place':['Kolhapur'],'age':25})
new_row
# Out:
#       name     place  age
# 0  Saurabh  Kolhapur   25

# %%
df
# Out:
#         name     place  age
# 0     Ashwin      Pune   42
# 1      Virat    Satara   20
# 2     Dinesh    Sangli   25
# 3      Rohit   Solapur   36
# 4     Hardik  Kolhapur   28
# 5   Ravindra      Pune   24
# 6      shami    Satara   45
# 7      Rahul    Sangli   25
# 8    Kuldeep   Solapur   21
# 9    Rishabh      Pune   19
# 10    Pujara    Satara   45

# %%
df.loc[4.5]=['saurabh','kolhapur',25]
df
# Out:
#           name     place  age
# 0.0     Ashwin      Pune   42
# 1.0      Virat    Satara   20
# 2.0     Dinesh    Sangli   25
# 3.0      Rohit   Solapur   36
# 4.0    saurabh  kolhapur   25
# 5.0   Ravindra      Pune   24
# 6.0      shami    Satara   45
# 7.0      Rahul    Sangli   25
# 8.0    Kuldeep   Solapur   21
# 9.0    Rishabh      Pune   19
# 10.0    Pujara    Satara   45
# 4.5    saurabh  kolhapur   25

# %%
df.sort_index().reset_index(drop=True)
# Out:
#         name     place  age
# 0     Ashwin      Pune   42
# 1      Virat    Satara   20
# 2     Dinesh    Sangli   25
# 3      Rohit   Solapur   36
# 4    saurabh  kolhapur   25
# 5    saurabh  kolhapur   25
# 6   Ravindra      Pune   24
# 7      shami    Satara   45
# 8      Rahul    Sangli   25
# 9    Kuldeep   Solapur   21
# 10   Rishabh      Pune   19
# 11    Pujara    Satara   45

# %%
df
# Out:
#         name     place  age
# 0     Ashwin      Pune   42
# 1      Virat    Satara   20
# 2     Dinesh    Sangli   25
# 3      Rohit   Solapur   36
# 4     Hardik  Kolhapur   28
# 5   Ravindra      Pune   24
# 6      shami    Satara   45
# 7      Rahul    Sangli   25
# 8    Kuldeep   Solapur   21
# 9    Rishabh      Pune   19
# 10    Pujara    Satara   45

# %%
pd.DataFrame(np.insert(df.values,3,new_row,axis=0))
# Out:
#            0         1   2
# 0     Ashwin      Pune  42
# 1      Virat    Satara  20
# 2     Dinesh    Sangli  25
# 3    Saurabh  Kolhapur  25
# 4      Rohit   Solapur  36
# 5     Hardik  Kolhapur  28
# 6   Ravindra      Pune  24
# 7      shami    Satara  45
# 8      Rahul    Sangli  25
# 9    Kuldeep   Solapur  21
# 10   Rishabh      Pune  19
# 11    Pujara    Satara  45

# %%
df.insert(3,'ID_no',np.random.randint(25,50,11),allow_duplicates=True)
df
# Out:
#         name     place  age  ID_no  ID_no  ID_no  ID_no  ID_no
# 0     Ashwin      Pune   42     45     28     43     28     45
# 1      Virat    Satara   20     36     35     43     29     28
# 2     Dinesh    Sangli   25     31     38     31     41     28
# 3      Rohit   Solapur   36     41     35     32     36     46
# 4     Hardik  Kolhapur   28     33     40     48     33     25
# 5   Ravindra      Pune   24     39     44     41     46     25
# 6      shami    Satara   45     37     44     43     48     32
# 7      Rahul    Sangli   25     39     49     42     36     40
# 8    Kuldeep   Solapur   21     43     31     45     34     48
# 9    Rishabh      Pune   19     34     41     49     45     26
# 10    Pujara    Satara   45     30     43     43     48     47
